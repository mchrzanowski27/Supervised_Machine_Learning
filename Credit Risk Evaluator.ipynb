# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier

# %%
train_df = pd.read_csv(Path('Resources/Generator/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/Generator/2020Q1loans.csv'))

# %%
train_df
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0          13375    0.1797       483.34       MORTGAGE    223000.0
# 1          21000    0.1308       478.68       MORTGAGE    123000.0
# 2          20000    0.1240       448.95       MORTGAGE    197000.0
# 3           3000    0.1240       100.22           RENT     45000.0
# 4          30000    0.1612      1056.49       MORTGAGE    133000.0
# ...          ...       ...          ...            ...         ...
# 12175      19975    0.2565       801.09           RENT     28000.0
# 12176      15000    0.1774       540.34           RENT     50000.0
# 12177       3600    0.1862       131.28           RENT     60000.0
# 12178      15000    0.0881       475.68       MORTGAGE     62000.0
# 12179      15000    0.1774       540.34           RENT     54080.0
#
#       verification_status loan_status pymnt_plan    dti  delinq_2yrs  ...  \
# 0            Not Verified    low_risk          n  29.99            0  ...
# 1         Source Verified    low_risk          n  11.26            2  ...
# 2         Source Verified    low_risk          n  11.28            0  ...
# 3            Not Verified    low_risk          n  18.08            0  ...
# 4         Source Verified    low_risk          n  27.77            0  ...
# ...                   ...         ...        ...    ...          ...  ...
# 12175        Not Verified   high_risk          n  28.42            0  ...
# 12176            Verified   high_risk          n  23.43            4  ...
# 12177        Not Verified   high_risk          n  28.80            0  ...
# 12178     Source Verified   high_risk          n  11.44            0  ...
# 12179        Not Verified   high_risk          n  21.66            1  ...
#
#        pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0               100.0              50.0                     0          0
# 1                85.0              33.3                     0          0
# 2                85.7              33.3                     0          0
# 3               100.0              16.7                     1          0
# 4               100.0              66.7                     0          0
# ...               ...               ...                   ...        ...
# 12175           100.0              16.7                     0          0
# 12176            90.5              11.1                     0          0
# 12177           100.0               0.0                     0          0
# 12178           100.0               0.0                     0          0
# 12179            90.0             100.0                     0          0
#
#        tot_hi_cred_lim total_bal_ex_mort  total_bc_limit  \
# 0               577150            122018           32000
# 1               132750             27896           15900
# 2               628160            114043           22600
# 3                42006             20761           19900
# 4               283248            109056           79500
# ...                ...               ...             ...
# 12175            50055             28192           18700
# 12176            70324             57025           13300
# 12177            83765             55156           14800
# 12178           189930             23748            7000
# 12179            48968             29786            2900
#
#        total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                          170200              N                     N
# 1                           35398              N                     N
# 2                           90340              N                     N
# 3                           15406              N                     N
# 4                           58778              N                     N
# ...                           ...            ...                   ...
# 12175                       19055              N                     N
# 12176                       54824              N                     N
# 12177                       53065              N                     N
# 12178                       32930              N                     N
# 12179                       33968              N                     N
#
# [12180 rows x 84 columns]

# %%
# Convert categorical data to numeric and separate target feature for training data

# %%
# train_df.to_csv('trainloans.csv', index=False)

# %%
# add missing dummy variables to testing set

# %%
# Train the Logistic Regression model on the unscaled data and print the model score

# %%
# Train a Random Forest Classifier model and print the model score

# %%
# Scale the data

# %%
# Train the Logistic Regression model on the scaled data and print the model score

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
